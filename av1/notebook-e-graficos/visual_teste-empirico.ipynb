# %%
import sys
sys.path.append("../")  # Adiciona o diretório raiz do projeto ao PATH

# Importar funções dos arquivos Python
from scripts2.graficos2 import plotar_grafico_insertion_sort
from scripts2.graficos2 import plotar_grafico_comparativo_insertion_sort
from scripts2.analise2 import gerar_dados_insertion

# Gerar os dados
n, f_de_n_aleatorio, f_de_n_crescente, f_de_n_decrescente = gerar_dados_insertion()

# Mostrar os gráficos individuais
plotar_grafico_insertion_sort(n, f_de_n_aleatorio, f_de_n_aleatorio, f_de_n_aleatorio, titulo="Dados Aleatórios")
plotar_grafico_insertion_sort(n, f_de_n_crescente, f_de_n_crescente, f_de_n_crescente, titulo="Dados ordenados Crescentemente")
plotar_grafico_insertion_sort(n, f_de_n_decrescente, f_de_n_decrescente, f_de_n_decrescente, titulo="Dados ordenados Decrescentemente")


# Mostrar o gráfico comparativo
plotar_grafico_comparativo_insertion_sort(n, f_de_n_aleatorio, f_de_n_crescente, f_de_n_decrescente, titulo="Comparação de Dados de Ordenação")
