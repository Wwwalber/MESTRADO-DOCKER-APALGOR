# %%
import sys
sys.path.append("../")  # Adiciona o diretório raiz do projeto ao PATH

# Importar funções dos arquivos Python
from scripts2.analise2 import gerar_dados
from scripts2.graficos2 import plotar_grafico
from scripts2.graficos2 import plotar_grafico_insertion_sort
from scripts2.analise2 import gerar_dados_insertion

# Gerar os dados
x, y = gerar_dados()
n, g = gerar_dados_insertion()

# Mostrar o gráfico
plotar_grafico(x, y)
plotar_grafico_insertion_sort(n, g)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 16
#      14 # Mostrar o gráfico
#      15 plotar_grafico(x, y)
# ---> 16 plotar_grafico_insertion_sort(n, g)
#
# File ~/Projetos/2024/MESTRADO-DOCKER-APALGOR/av1/notebook/../scripts2/graficos2.py:19, in plotar_grafico_insertion_sort(n, g)
#      16 plt.figure(figsize=(12, 8))
#      18 # Gráfico dos resultados empíricos
# ---> 19 plt.plot(n, g, 'o', label='Testes Empíricos (Insertion Sort)', color='orange')
#      21 # Gráficos das funções teóricas
#      22 #plt.plot(n, f, 'r-', label='f(n) = 0.5n^2 + 3n')
#      23 #plt.plot(n, g, 'b-', label='g(n) = n^2')
#      24
#      25 # Adicionar elementos ao gráfico
#      26 plt.title('Comparação dos Testes Empíricos e Funções Teóricas')
#
# File ~/Projetos/2024/MESTRADO-DOCKER-APALGOR/.venv-apa01/lib/python3.12/site-packages/matplotlib/pyplot.py:3829, in plot(scalex, scaley, data, *args, **kwargs)
#    3821 @_copy_docstring_and_deprecators(Axes.plot)
#    3822 def plot(
#    3823     *args: float | ArrayLike | str,
#    (...)
#    3827     **kwargs,
#    3828 ) -> list[Line2D]:
# -> 3829     return gca().plot(
#    3830         *args,
#    3831         scalex=scalex,
#    3832         scaley=scaley,
#    3833         **({"data": data} if data is not None else {}),
#    3834         **kwargs,
#    3835     )
#
# File ~/Projetos/2024/MESTRADO-DOCKER-APALGOR/.venv-apa01/lib/python3.12/site-packages/matplotlib/axes/_axes.py:1777, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1534 """
#    1535 Plot y versus x as lines and/or markers.
#    1536
#    (...)
#    1774 (``'green'``) or hex strings (``'#008000'``).
#    1775 """
#    1776 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1777 lines = [*self._get_lines(self, *args, data=data, **kwargs)]
#    1778 for line in lines:
#    1779     self.add_line(line)
#
# File ~/Projetos/2024/MESTRADO-DOCKER-APALGOR/.venv-apa01/lib/python3.12/site-packages/matplotlib/axes/_base.py:297, in _process_plot_var_args.__call__(self, axes, data, return_kwargs, *args, **kwargs)
#     295     this += args[0],
#     296     args = args[1:]
# --> 297 yield from self._plot_args(
#     298     axes, this, kwargs, ambiguous_fmt_datakey=ambiguous_fmt_datakey,
#     299     return_kwargs=return_kwargs
#     300 )
#
# File ~/Projetos/2024/MESTRADO-DOCKER-APALGOR/.venv-apa01/lib/python3.12/site-packages/matplotlib/axes/_base.py:494, in _process_plot_var_args._plot_args(self, axes, tup, kwargs, return_kwargs, ambiguous_fmt_datakey)
#     491     axes.yaxis.update_units(y)
#     493 if x.shape[0] != y.shape[0]:
# --> 494     raise ValueError(f"x and y must have same first dimension, but "
#     495                      f"have shapes {x.shape} and {y.shape}")
#     496 if x.ndim > 2 or y.ndim > 2:
#     497     raise ValueError(f"x and y can be no greater than 2D, but have "
#     498                      f"shapes {x.shape} and {y.shape}")
#
# ValueError: x and y must have same first dimension, but have shapes (1,) and (50,)
