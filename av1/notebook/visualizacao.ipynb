# %%
import sys
sys.path.append("../")  # Adiciona o diretório raiz do projeto ao PATH

# Importar funções dos arquivos Python
from scripts.analise import gerar_dados
from scripts.graficos import plotar_grafico

# Gerar os dados
x, y = gerar_dados()

# Mostrar o gráfico
plotar_grafico(x, y)
