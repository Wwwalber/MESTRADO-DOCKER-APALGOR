# %%
import numpy as np
import matplotlib.pyplot as plt

# Definir o intervalo de valores para n
n = np.linspace(1, 100, 100)  # Cria 100 pontos entre 1 e 100

# Definir as funções
f = 0.5 * n**2 + 3 * n
g = n**2
h = 3*n
# Criar o gráfico
plt.figure(figsize=(10, 6))

# Plotar as funções
plt.plot(n, f, 'r-', label='f(n) = 0.5n^2 + 3n')
plt.plot(n, g, 'b-', label='g(n) = n^2')
plt.plot(n, h, 'g-', label='h(n) = h = 3*n' )

# Adicionar elementos ao gráfico
plt.title('Comparação das Funções f(n), g(n) e h(n)')
plt.xlabel('n')
plt.ylabel('Valores das Funções')
plt.grid(True)
plt.legend()

# Mostrar o gráfico
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import math  # Precisamos importar o módulo math

# Definir o intervalo de valores para n
n = np.linspace(1, 20, 100000)  # Aumentando o número de pontos para melhor visualização

# Definir as funções
a = np.log2(n)
b = n
c = n * np.log2(n)
d = n**2

# Para o fatorial, usando math.factorial
def factorial_array(n):
    return np.array([math.factorial(int(i)) for i in n])

e = factorial_array(n)

# Criar o gráfico
plt.figure(figsize=(10, 6))

# Plotar as funções
plt.plot(n, a, 'r-', label='O(log n)')
plt.plot(n, b, 'b-', label='O(n)')
plt.plot(n, c, 'g-', label='O(n log n)')
plt.plot(n, d, 'y-', label='O(n^2)')
plt.plot(n, e, 'm-', label='O(n!)')

# Adicionar elementos ao gráfico
plt.title('Comparação das Funções')
plt.xlabel('n')
plt.ylabel('Valores das Funções')
plt.grid(True)
plt.legend()
plt.yscale('log')

# Mostrar o gráfico
plt.show()
